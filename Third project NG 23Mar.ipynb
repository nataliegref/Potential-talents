# %% [markdown]
# # Project 3
# ## Goal(s):
#
# Predict how fit the candidate is based on their available information (variable fit)
#
# ## Success Metric(s):
#
# Rank candidates based on a fitness score.
#
# Re-rank candidates when a candidate is starred.
#
# ## Bonus(es):
#
# We are interested in a robust algorithm, tell us how your solution works and show us how your ranking gets better with each starring action.
#
# How can we filter out candidates which in the first place should not be in this list?
#
# Can we determine a cut-off point that would work for other roles without losing high potential candidates?
#
# Do you have any ideas that we should explore so that we can even automate this procedure to prevent human bias?

# %%
# linear algebra
import numpy as np 

# data processing
import pandas as pd 

# data visualization
import seaborn as sns
# %matplotlib inline
from matplotlib import pyplot as plt
from matplotlib import style

# Algorithms
from sklearn import linear_model
from sklearn.linear_model import Perceptron
from sklearn.linear_model import SGDClassifier
from sklearn.svm import SVC, LinearSVC
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neural_network import MLPClassifier
import xgboost as xgb
import lightgbm as lgb


#Cross validation
from sklearn.model_selection import KFold, cross_val_score

#Other
from sklearn import metrics
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import classification_report
from sklearn.feature_selection import SelectKBest, chi2
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score

#class imbalance
from sklearn.metrics import f1_score
from sklearn.utils import resample

#embedding using BERT

from transformers import AutoTokenizer, AutoModel
from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# # Loading data

# %%
og_data = pd.read_excel('potential-talents.xlsx')
data = og_data
keywords = 'aspiring human resources'

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104 entries, 0 to 103
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          104 non-null    int64
#  1   job_title   104 non-null    object
#  2   location    104 non-null    object
#  3   connection  104 non-null    object
#  4   fit         0 non-null      float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 4.2+ KB

# %%
data.columns
# Out:
# Index(['id', 'job_title', 'location', 'connection', 'fit'], dtype='object')

# %%
data.describe()
# Out:
#                id  fit
# count  104.000000  0.0
# mean    52.500000  NaN
# std     30.166206  NaN
# min      1.000000  NaN
# 25%     26.750000  NaN
# 50%     52.500000  NaN
# 75%     78.250000  NaN
# max    104.000000  NaN

# %%
data.head(55)
# Out:
#     id                                          job_title  \
# 0    1  2019 C.T. Bauer College of Business Graduate (...
# 1    2  Native English Teacher at EPIK (English Progra...
# 2    3              Aspiring Human Resources Professional
# 3    4             People Development Coordinator at Ryan
# 4    5    Advisory Board Member at Celal Bayar University
# 5    6                Aspiring Human Resources Specialist
# 6    7  Student at Humber College and Aspiring Human R...
# 7    8                               HR Senior Specialist
# 8    9  Student at Humber College and Aspiring Human R...
# 9   10  Seeking Human Resources HRIS and Generalist Po...
# 10  11                      Student at Chapman University
# 11  12  SVP, CHRO, Marketing & Communications, CSR Off...
# 24                               Kanada         61  NaN
# 25               San Francisco Bay Area      500+   NaN
# 26                  Houston, Texas Area      500+   NaN
# 27                    Chicago, Illinois        390  NaN
# 28                  Houston, Texas Area      500+   NaN
# 29                    Chicago, Illinois        390  NaN
# 30                       Houston, Texas         85  NaN
# 31                               Kanada      500+   NaN
# 32  Raleigh-Durham, North Carolina Area         44  NaN
# 33                        Denton, Texas      500+   NaN
# 34                       İzmir, Türkiye      500+   NaN
# 35           Greater New York City Area          1  NaN
# 36                               Kanada         61  NaN
# 37               San Francisco Bay Area      500+   NaN
# 38                               Kanada         61  NaN
# 39            Greater Philadelphia Area      500+   NaN
# 40              Lake Forest, California          2  NaN
# 41                  Houston, Texas Area      500+   NaN
# 42                     Atlanta, Georgia      500+   NaN
# 43                       Houston, Texas         85  NaN
# 44                               Kanada      500+   NaN
# 45  Raleigh-Durham, North Carolina Area         44  NaN
# 46                        Denton, Texas      500+   NaN
# 47                       İzmir, Türkiye      500+   NaN
# 48           Greater New York City Area          1  NaN
# 49                               Kanada         61  NaN
# 50               San Francisco Bay Area      500+   NaN
# 51                               Kanada         61  NaN
# 52            Greater Philadelphia Area      500+   NaN
# 53              Lake Forest, California          2  NaN
# 54                  Houston, Texas Area      500+   NaN

# %% [markdown]
# Attributes:
# id : unique identifier for candidate (numeric)
#
# job_title : job title for candidate (text)
#
# location : geographical location for candidate (text)
#
# connections: number of connections candidate has, 500+ means over 500 (text)

# %%
print('title: ', data.job_title.unique())
print('location: ', data.location.unique())
print('connections: ', data.connection.unique())
# Out:
# title:  ['2019 C.T. Bauer College of Business Graduate (Magna Cum Laude) and aspiring Human Resources professional'
#  'Native English Teacher at EPIK (English Program in Korea)'
#  'Aspiring Human Resources Professional'
#  'People Development Coordinator at Ryan'
#  'Advisory Board Member at Celal Bayar University'
#  'Aspiring Human Resources Specialist'
#  'Student at Humber College and Aspiring Human Resources Generalist'
#  'HR Senior Specialist'
#  'Seeking Human Resources HRIS and Generalist Positions'
#  'Student at Chapman University'
#  'SVP, CHRO, Marketing & Communications, CSR Officer | ENGIE | Houston | The Woodlands | Energy | GPHR | SPHR'
#  'Human Resources Coordinator at InterContinental Buckhead Atlanta'
#  'Aspiring Human Resources Management student seeking an internship'
#  'Seeking Human Resources Opportunities'
#  'Experienced Retail Manager and aspiring Human Resources Professional'
#  'Human Resources, Staffing and Recruiting Professional'
#  'Human Resources Specialist at Luxottica'
#  'Director of Human Resources North America, Groupe Beneteau'
#  'Retired Army National Guard Recruiter, office manager,  seeking a position in Human Resources.'
#  'Human Resources Generalist at ScottMadden, Inc.'
#  'Business Management Major and Aspiring Human Resources Manager'
#  'Aspiring Human Resources Manager, seeking internship in Human Resources.'
#  'Human Resources Professional'
#  'Nortia Staffing is seeking Human Resources, Payroll & Administrative Professionals!!  (408) 709-2621'
#  'Aspiring Human Resources Professional | Passionate about helping to create an inclusive and engaging work environment'
#  'Human Resources|\nConflict Management|\nPolicies & Procedures|Talent Management|Benefits & Compensation'
#  "Human Resources Generalist at Schwan's"
#  'Liberal Arts Major. Aspiring Human Resources Analyst.'
#  'Junior MES Engineer| Information Systems'
#  'Senior Human Resources Business Partner at Heil Environmental'
#  'Aspiring Human Resources Professional | An energetic and Team-Focused Leader'
#  'HR Manager at Endemol Shine North America'
#  'Human Resources professional for the world leader in GIS software'
#  'RRP Brand Portfolio Executive at JTI (Japan Tobacco International)'
#  'Information Systems Specialist and Programmer with a love for data and organization.'
#  'Bachelor of Science in Biology from Victoria University of Wellington'
#  'Human Resources Management Major' 'Director Human Resources  at EY'
#  'Undergraduate Research Assistant at Styczynski Lab'
#  'Lead Official at Western Illinois University'
#  'Seeking employment opportunities within Customer Service or Patient Care'
#  'Admissions Representative at Community medical center long beach'
#  'Seeking Human  Resources Opportunities. Open to travel and relocation.'
#  'Student at Westfield State University'
#  'Student at Indiana University Kokomo - Business Management - \nRetail Manager at Delphi Hardware and Paint'
#  'Student' 'Seeking Human Resources Position'
#  'Aspiring Human Resources Manager | Graduating May 2020 | Seeking an Entry-Level Human Resources Position in St. Louis'
#  'Human Resources Generalist at Loparex'
#  'Business Intelligence and Analytics at Travelers'
#  'Always set them up for Success'
#  'Director Of Administration at Excellence Logging']
# location:  ['Houston, Texas' 'Kanada' 'Raleigh-Durham, North Carolina Area'
#  'Denton, Texas' 'İzmir, Türkiye' 'Greater New York City Area'
#  'San Francisco Bay Area' 'Greater Philadelphia Area'
#  'Lake Forest, California' 'Houston, Texas Area' 'Atlanta, Georgia'
#  'Chicago, Illinois' 'Austin, Texas Area' 'Jackson, Mississippi Area'
#  'Greater Grand Rapids, Michigan Area' 'Virginia Beach, Virginia'
#  'Monroe, Louisiana Area' 'Greater Boston Area' 'San Jose, California'
#  'New York, New York' 'Dallas/Fort Worth Area'
#  'Amerika Birleşik Devletleri' 'Baton Rouge, Louisiana Area'
#  'Myrtle Beach, South Carolina Area' 'Chattanooga, Tennessee Area'
#  'Los Angeles, California' 'Highland, California' 'Gaithersburg, Maryland'
#  'Baltimore, Maryland' 'Milpitas, California' 'Greater Atlanta Area'
#  'Greater Chicago Area' 'Torrance, California' 'Long Beach, California'
#  'Bridgewater, Massachusetts' 'Lafayette, Indiana' 'Kokomo, Indiana Area'
#  'Las Vegas, Nevada Area' 'Cape Girardeau, Missouri'
#  'Greater Los Angeles Area' 'Katy, Texas']
# connections:  [85 '500+ ' 44 1 61 2 390 57 82 5 7 16 212 409 52 455 174 268 50 4 40 18
#  349 155 39 64 9 415 19 71 48 103 49]

# %% [markdown]
# # Processing data

# %%
#First we will normalize the connections to be between 0-1. We will count 500+ as 500

# Function to normalize scores to between 0-1
def normalize_score(score):
    if score == '500+ ':
        score = 500
    return float(score)/500

# Applying the function to the 'connection' column to create a new 'normalized_connections' column
data['normalized_connections'] = data['connection'].apply(normalize_score)

# %%
#We will then calculate the similarity between the job titles and the given keyword (stored as variable 'keywords' in the top of the code, at first it we use 'aspiring human resources')

# Load the BERT tokenizer and model
tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")
model = AutoModel.from_pretrained("bert-base-uncased")

# Tokenize and encode the job titles using BERT
job_title_encodings = data["job_title"].apply(
    lambda title: model(**tokenizer(title, return_tensors="pt")).pooler_output.detach().numpy()
)

# Compute the cosine similarity between the encoded job titles and the keyword
keyword_encoding = model(**tokenizer(keywords, return_tensors="pt")).pooler_output.detach().numpy()
similarity_scores = np.vstack(job_title_encodings.apply(lambda encoding: cosine_similarity(encoding, keyword_encoding))).ravel()

# Add the similarity scores as a new column in the DataFrame
data["similarity_score"] = similarity_scores
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertModel: ['cls.predictions.transform.dense.bias', 'cls.predictions.bias', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
data.head()
# Out:
#    id                                          job_title  \
# 0   1  2019 C.T. Bauer College of Business Graduate (...
# 1   2  Native English Teacher at EPIK (English Progra...
# 2   3              Aspiring Human Resources Professional
# 3   4             People Development Coordinator at Ryan
# 4   5    Advisory Board Member at Celal Bayar University
#
#                               location connection  fit  \
# 0                       Houston, Texas         85  NaN
# 1                               Kanada      500+   NaN
# 2  Raleigh-Durham, North Carolina Area         44  NaN
# 3                        Denton, Texas      500+   NaN
# 4                       İzmir, Türkiye      500+   NaN
#
#    normalized_connections  similarity_score
# 0                   0.170          0.764336
# 1                   1.000          0.899860
# 2                   0.088          0.937843
# 3                   1.000          0.984712
# 4                   1.000          0.824166

# %%
#now make a new column fitness score based on an equation taking similarity_score and normalized_connections

# calculate the new column based on the equation
data['fitness_score'] = data['similarity_score'] * 0.9 + data['normalized_connections'] * 0.1
data = data.sort_values(by='fitness_score', ascending=False)
data.head(20)
# Out:
#       id                                          job_title  \
# 46    47             People Development Coordinator at Ryan
# 58    59             People Development Coordinator at Ryan
# 3      4             People Development Coordinator at Ryan
# 33    34             People Development Coordinator at Ryan
# 21    22             People Development Coordinator at Ryan
# 17    18             People Development Coordinator at Ryan
# 60    61                               HR Senior Specialist
# 25    26                               HR Senior Specialist
# 37    38                               HR Senior Specialist
# 50    51                               HR Senior Specialist
# 7      8                               HR Senior Specialist
# 102  103                     Always set them up for Success
# 29    30              Seeking Human Resources Opportunities
# 27    28              Seeking Human Resources Opportunities
# 67    68            Human Resources Specialist at Luxottica
# 55    56  Human Resources Coordinator at InterContinenta...
# 64    65  Human Resources Coordinator at InterContinenta...
# 42    43  Human Resources Coordinator at InterContinenta...
# 12    13  Human Resources Coordinator at InterContinenta...
# 100  101              Human Resources Generalist at Loparex
#
#                                 location connection  fit  \
# 46                         Denton, Texas      500+   NaN
# 58                         Denton, Texas      500+   NaN
# 3                          Denton, Texas      500+   NaN
# 33                         Denton, Texas      500+   NaN
# 21                         Denton, Texas      500+   NaN
# 17                         Denton, Texas      500+   NaN
# 60                San Francisco Bay Area      500+   NaN
# 25                San Francisco Bay Area      500+   NaN
# 37                San Francisco Bay Area      500+   NaN
# 50                San Francisco Bay Area      500+   NaN
# 7                 San Francisco Bay Area      500+   NaN
# 102             Greater Los Angeles Area      500+   NaN
# 29                     Chicago, Illinois        390  NaN
# 27                     Chicago, Illinois        390  NaN
# 67            Greater New York City Area      500+   NaN
# 55                      Atlanta, Georgia      500+   NaN
# 64                      Atlanta, Georgia      500+   NaN
# 42                      Atlanta, Georgia      500+   NaN
# 12                      Atlanta, Georgia      500+   NaN
# 100  Raleigh-Durham, North Carolina Area      500+   NaN
#
#      normalized_connections  similarity_score  fitness_score
# 46                     1.00          0.984712       0.986241
# 58                     1.00          0.984712       0.986241
# 3                      1.00          0.984712       0.986241
# 33                     1.00          0.984712       0.986241
# 21                     1.00          0.984712       0.986241
# 17                     1.00          0.984712       0.986241
# 60                     1.00          0.982888       0.984600
# 25                     1.00          0.982888       0.984600
# 37                     1.00          0.982888       0.984600
# 50                     1.00          0.982888       0.984600
# 7                      1.00          0.982888       0.984600
# 102                    1.00          0.968243       0.971418
# 29                     0.78          0.986173       0.965555
# 27                     0.78          0.986173       0.965555
# 67                     1.00          0.961368       0.965231
# 55                     1.00          0.944081       0.949673
# 64                     1.00          0.944081       0.949673
# 42                     1.00          0.944081       0.949673
# 12                     1.00          0.944081       0.949673
# 100                    1.00          0.940202       0.946181

# %% [markdown]
# # Starring candidates

# %%
# add a new column named 'starred' and set all values to 0
data['starred'] = 0

# set the value of the 7th row in 'starred' to 1 as an example
data.loc[7, 'starred'] = 1

#update the fitness_score based on starring
data['fitness_score'] = data['similarity_score'] * 0.9 + data['normalized_connections'] * 0.1 + data['starred']
data = data.sort_values(by='fitness_score', ascending=False)
# print the updated dataframe
data.head(20)
# Out:
#       id                                          job_title  \
# 7      8                               HR Senior Specialist
# 46    47             People Development Coordinator at Ryan
# 58    59             People Development Coordinator at Ryan
# 3      4             People Development Coordinator at Ryan
# 33    34             People Development Coordinator at Ryan
# 21    22             People Development Coordinator at Ryan
# 17    18             People Development Coordinator at Ryan
# 60    61                               HR Senior Specialist
# 25    26                               HR Senior Specialist
# 37    38                               HR Senior Specialist
# 50    51                               HR Senior Specialist
# 102  103                     Always set them up for Success
# 27    28              Seeking Human Resources Opportunities
# 29    30              Seeking Human Resources Opportunities
# 67    68            Human Resources Specialist at Luxottica
# 55    56  Human Resources Coordinator at InterContinenta...
# 64    65  Human Resources Coordinator at InterContinenta...
# 42    43  Human Resources Coordinator at InterContinenta...
# 12    13  Human Resources Coordinator at InterContinenta...
# 100  101              Human Resources Generalist at Loparex
#
#                                 location connection  fit  \
# 7                 San Francisco Bay Area      500+   NaN
# 46                         Denton, Texas      500+   NaN
# 58                         Denton, Texas      500+   NaN
# 3                          Denton, Texas      500+   NaN
# 33                         Denton, Texas      500+   NaN
# 21                         Denton, Texas      500+   NaN
# 17                         Denton, Texas      500+   NaN
# 60                San Francisco Bay Area      500+   NaN
# 25                San Francisco Bay Area      500+   NaN
# 37                San Francisco Bay Area      500+   NaN
# 50                San Francisco Bay Area      500+   NaN
# 102             Greater Los Angeles Area      500+   NaN
# 27                     Chicago, Illinois        390  NaN
# 29                     Chicago, Illinois        390  NaN
# 67            Greater New York City Area      500+   NaN
# 55                      Atlanta, Georgia      500+   NaN
# 64                      Atlanta, Georgia      500+   NaN
# 42                      Atlanta, Georgia      500+   NaN
# 12                      Atlanta, Georgia      500+   NaN
# 100  Raleigh-Durham, North Carolina Area      500+   NaN
#
#      normalized_connections  similarity_score  fitness_score  starred
# 7                      1.00          0.982888       1.984600        1
# 46                     1.00          0.984712       0.986241        0
# 58                     1.00          0.984712       0.986241        0
# 3                      1.00          0.984712       0.986241        0
# 33                     1.00          0.984712       0.986241        0
# 21                     1.00          0.984712       0.986241        0
# 17                     1.00          0.984712       0.986241        0
# 60                     1.00          0.982888       0.984600        0
# 25                     1.00          0.982888       0.984600        0
# 37                     1.00          0.982888       0.984600        0
# 50                     1.00          0.982888       0.984600        0
# 102                    1.00          0.968243       0.971418        0
# 27                     0.78          0.986173       0.965555        0
# 29                     0.78          0.986173       0.965555        0
# 67                     1.00          0.961368       0.965231        0
# 55                     1.00          0.944081       0.949673        0
# 64                     1.00          0.944081       0.949673        0
# 42                     1.00          0.944081       0.949673        0
# 12                     1.00          0.944081       0.949673        0
# 100                    1.00          0.940202       0.946181        0

# %%
# set the value of the 3rd, 4th, 5th, row in 'starred' to 1 as more example
data.loc[27, 'starred'] = 1
data.loc[55, 'starred'] = 1
data.loc[100, 'starred'] = 1

#update the fitness_score based on starring
data['fitness_score'] = data['similarity_score'] * 0.9 + data['normalized_connections'] * 0.1 + data['starred']
data = data.sort_values(by='fitness_score', ascending=False)
# print the updated dataframe
data.head()
# Out:
#       id                                          job_title  \
# 7      8                               HR Senior Specialist
# 27    28              Seeking Human Resources Opportunities
# 55    56  Human Resources Coordinator at InterContinenta...
# 100  101              Human Resources Generalist at Loparex
# 58    59             People Development Coordinator at Ryan
#
#                                 location connection  fit  \
# 7                 San Francisco Bay Area      500+   NaN
# 27                     Chicago, Illinois        390  NaN
# 55                      Atlanta, Georgia      500+   NaN
# 100  Raleigh-Durham, North Carolina Area      500+   NaN
# 58                         Denton, Texas      500+   NaN
#
#      normalized_connections  similarity_score  fitness_score  starred
# 7                      1.00          0.982888       1.984600        1
# 27                     0.78          0.986173       1.965555        1
# 55                     1.00          0.944081       1.949673        1
# 100                    1.00          0.940202       1.946181        1
# 58                     1.00          0.984712       0.986241        0

# %% [markdown]
# # Model

# %%
def ranking_model(data):
    #make x and y
    feature_cols = ['normalized_connections', 'similarity_score']
    X = data[feature_cols]
    y = data.starred 
    
    #split data into training and testing, check both have starred items
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
    # Make sure at least one example of data with positive supervisory signal is in the training set
    print("Number of ranked items in training set:", y_train.sum())
    print("Number of ranked items in test set:",y_test.sum())
    while y_train.sum() ==0 or y_test.sum()== 0:
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
        # Make sure at least one example of data with positive supervisory signal is in the training set
        print("Number of ranked items in training set:", y_train.sum())
        print("Number of ranked items in test set:",y_test.sum())
    X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2)
    
    #define queries
    query_train = [X_train.shape[0]]
    query_val = [X_val.shape[0]]
    query_test = [X_test.shape[0]]

    # Train the LightGBM model
    
    gbm = lgb.LGBMRanker(
    objective="lambdarank",
    metric="ndcg",)
    
    gbm.fit(X_train, y_train, group=query_train,
        eval_set=[(X_val, y_val)], eval_group=[query_val],
        eval_at=[5, 10, 20], early_stopping_rounds=50)


    # predict on test set and return
    return gbm.predict(X)

# %%
predictions = ranking_model(data)
# Out:
# Number of ranked items in training set: 3
# Number of ranked items in test set: 1
# [1]	valid_0's ndcg@5: 1	valid_0's ndcg@10: 1	valid_0's ndcg@20: 1
# Training until validation scores don't improve for 50 rounds
# [2]	valid_0's ndcg@5: 1	valid_0's ndcg@10: 1	valid_0's ndcg@20: 1
# [3]	valid_0's ndcg@5: 1	valid_0's ndcg@10: 1	valid_0's ndcg@20: 1
# [4]	valid_0's ndcg@5: 1	valid_0's ndcg@10: 1	valid_0's ndcg@20: 1
# [5]	valid_0's ndcg@5: 1	valid_0's ndcg@10: 1	valid_0's ndcg@20: 1
# [6]	valid_0's ndcg@5: 1	valid_0's ndcg@10: 1	valid_0's ndcg@20: 1
# [7]	valid_0's ndcg@5: 1	valid_0's ndcg@10: 1	valid_0's ndcg@20: 1
# [8]	valid_0's ndcg@5: 1	valid_0's ndcg@10: 1	valid_0's ndcg@20: 1
# [9]	valid_0's ndcg@5: 1	valid_0's ndcg@10: 1	valid_0's ndcg@20: 1
# [10]	valid_0's ndcg@5: 1	valid_0's ndcg@10: 1	valid_0's ndcg@20: 1
# [11]	valid_0's ndcg@5: 1	valid_0's ndcg@10: 1	valid_0's ndcg@20: 1
# [12]	valid_0's ndcg@5: 1	valid_0's ndcg@10: 1	valid_0's ndcg@20: 1
# [13]	valid_0's ndcg@5: 1	valid_0's ndcg@10: 1	valid_0's ndcg@20: 1
# [14]	valid_0's ndcg@5: 1	valid_0's ndcg@10: 1	valid_0's ndcg@20: 1
# [15]	valid_0's ndcg@5: 1	valid_0's ndcg@10: 1	valid_0's ndcg@20: 1
# [16]	valid_0's ndcg@5: 1	valid_0's ndcg@10: 1	valid_0's ndcg@20: 1
# [17]	valid_0's ndcg@5: 1	valid_0's ndcg@10: 1	valid_0's ndcg@20: 1
# [18]	valid_0's ndcg@5: 1	valid_0's ndcg@10: 1	valid_0's ndcg@20: 1
# [19]	valid_0's ndcg@5: 1	valid_0's ndcg@10: 1	valid_0's ndcg@20: 1
# [20]	valid_0's ndcg@5: 1	valid_0's ndcg@10: 1	valid_0's ndcg@20: 1
# [21]	valid_0's ndcg@5: 1	valid_0's ndcg@10: 1	valid_0's ndcg@20: 1
# Early stopping, best iteration is:
# [1]	valid_0's ndcg@5: 1	valid_0's ndcg@10: 1	valid_0's ndcg@20: 1

# %% [markdown]
# # Updating fitness and ranking

# %%
#rank based on model output
df = data
df['ranking'] = predictions
df = df.sort_values(by="ranking", ascending=False)

# %%
df.head()
# Out:
#     id                                     job_title  \
# 7    8                          HR Senior Specialist
# 23  24           Aspiring Human Resources Specialist
# 77  78        Human Resources Generalist at Schwan's
# 98  99              Seeking Human Resources Position
# 90  91  Lead Official at Western Illinois University
#
#                        location connection  fit  normalized_connections  \
# 7        San Francisco Bay Area      500+   NaN                   1.000
# 23   Greater New York City Area          1  NaN                   0.002
# 77  Amerika Birleşik Devletleri      500+   NaN                   1.000
# 98       Las Vegas, Nevada Area         48  NaN                   0.096
# 90         Greater Chicago Area         39  NaN                   0.078
#
#     similarity_score  fitness_score  starred   ranking
# 7           0.982888       1.984600        1  0.108387
# 23          0.969603       0.872843        0  0.108387
# 77          0.939072       0.945165        0  0.108387
# 98          0.986825       0.897743        0  0.108387
# 90          0.962510       0.874059        0  0.108387

# %%
#reset dataframe index
df = df.reset_index()
#find where the starred items are now
df.loc[df['starred'] == 1]
# Out:
#     index   id                                          job_title  \
# 0       7    8                               HR Senior Specialist
# 15     27   28              Seeking Human Resources Opportunities
# 30    100  101              Human Resources Generalist at Loparex
# 31     55   56  Human Resources Coordinator at InterContinenta...
#
#                                location connection  fit  \
# 0                San Francisco Bay Area      500+   NaN
# 15                    Chicago, Illinois        390  NaN
# 30  Raleigh-Durham, North Carolina Area      500+   NaN
# 31                     Atlanta, Georgia      500+   NaN
#
#     normalized_connections  similarity_score  fitness_score  starred   ranking
# 0                     1.00          0.982888       1.984600        1  0.108387
# 15                    0.78          0.986173       1.965555        1  0.108387
# 30                    1.00          0.940202       1.946181        1  0.108387
# 31                    1.00          0.944081       1.949673        1  0.108387

# %% [markdown]
# Problem: Starred rows are dispersed through the newly ranked dataset

# %% [markdown]
# # Trying with more starred candidates

# %%
data.head(50)
# Out:
#       id                                          job_title  \
# 7      8                               HR Senior Specialist
# 27    28              Seeking Human Resources Opportunities
# 55    56  Human Resources Coordinator at InterContinenta...
# 100  101              Human Resources Generalist at Loparex
# 58    59             People Development Coordinator at Ryan
# 3      4             People Development Coordinator at Ryan
# 33    34             People Development Coordinator at Ryan
# 21    22             People Development Coordinator at Ryan
# 17    18             People Development Coordinator at Ryan
# 46    47             People Development Coordinator at Ryan
# 60    61                               HR Senior Specialist
# 25    26                               HR Senior Specialist
# 37    38                               HR Senior Specialist
# 50    51                               HR Senior Specialist
# 102  103                     Always set them up for Success
# 29    30              Seeking Human Resources Opportunities
# 67    68            Human Resources Specialist at Luxottica
# 64    65  Human Resources Coordinator at InterContinenta...
# 42    43  Human Resources Coordinator at InterContinenta...
# 12    13  Human Resources Coordinator at InterContinenta...
# 77    78             Human Resources Generalist at Schwan's
# 19    20  Native English Teacher at EPIK (English Progra...
# 44    45  Native English Teacher at EPIK (English Progra...
# 15    16  Native English Teacher at EPIK (English Progra...
# 31    32  Native English Teacher at EPIK (English Progra...
# 1      2  Native English Teacher at EPIK (English Progra...
# 98    99                   Seeking Human Resources Position
# 103  104   Director Of Administration at Excellence Logging
# 80    81  Senior Human Resources Business Partner at Hei...
# 90    91       Lead Official at Western Illinois University
# 59    60                Aspiring Human Resources Specialist
# 5      6                Aspiring Human Resources Specialist
# 48    49                Aspiring Human Resources Specialist
# 23    24                Aspiring Human Resources Specialist
# 35    36                Aspiring Human Resources Specialist
# 28    29  Aspiring Human Resources Management student se...
# 26    27  Aspiring Human Resources Management student se...
# 84    85  RRP Brand Portfolio Executive at JTI (Japan To...
# 40    41                      Student at Chapman University
# 53    54                      Student at Chapman University
# 10    11                      Student at Chapman University
# 62    63                      Student at Chapman University
# 73    74                       Human Resources Professional
# 88    89                    Director Human Resources  at EY
# 96    97              Aspiring Human Resources Professional
# 97    98                                            Student
# 16    17              Aspiring Human Resources Professional
# 2      3              Aspiring Human Resources Professional
# 57    58              Aspiring Human Resources Professional
# 45    46              Aspiring Human Resources Professional
#
#                                 location connection  fit  \
# 7                 San Francisco Bay Area      500+   NaN
# 27                     Chicago, Illinois        390  NaN
# 55                      Atlanta, Georgia      500+   NaN
# 100  Raleigh-Durham, North Carolina Area      500+   NaN
# 58                         Denton, Texas      500+   NaN
# 3                          Denton, Texas      500+   NaN
# 33                         Denton, Texas      500+   NaN
# 21                         Denton, Texas      500+   NaN
# 17                         Denton, Texas      500+   NaN
# 46                         Denton, Texas      500+   NaN
# 60                San Francisco Bay Area      500+   NaN
# 25                San Francisco Bay Area      500+   NaN
# 37                San Francisco Bay Area      500+   NaN
# 50                San Francisco Bay Area      500+   NaN
# 102             Greater Los Angeles Area      500+   NaN
# 29                     Chicago, Illinois        390  NaN
# 67            Greater New York City Area      500+   NaN
# 64                      Atlanta, Georgia      500+   NaN
# 42                      Atlanta, Georgia      500+   NaN
# 12                      Atlanta, Georgia      500+   NaN
# 77           Amerika Birleşik Devletleri      500+   NaN
# 19                                Kanada      500+   NaN
# 44                                Kanada      500+   NaN
# 15                                Kanada      500+   NaN
# 31                                Kanada      500+   NaN
# 1                                 Kanada      500+   NaN
# 98                Las Vegas, Nevada Area         48  NaN
# 103                          Katy, Texas      500+   NaN
# 80           Chattanooga, Tennessee Area        455  NaN
# 90                  Greater Chicago Area         39  NaN
# 59            Greater New York City Area          1  NaN
# 5             Greater New York City Area          1  NaN
# 48            Greater New York City Area          1  NaN
# 23            Greater New York City Area          1  NaN
# 35            Greater New York City Area          1  NaN
# 28                   Houston, Texas Area      500+   NaN
# 26                   Houston, Texas Area      500+   NaN
# 84             Greater Philadelphia Area      500+   NaN
# 40               Lake Forest, California          2  NaN
# 53               Lake Forest, California          2  NaN
# 10               Lake Forest, California          2  NaN
# 62               Lake Forest, California          2  NaN
# 73                   Greater Boston Area         16  NaN
# 88                  Greater Atlanta Area        349  NaN
# 103 -0.200000
# 80  -0.200000
# 90   0.108387
# 59   0.108387
# 5    0.108387
# 48   0.108387
# 23   0.108387
# 35   0.108387
# 28  -0.200000
# 26  -0.200000
# 84  -0.200000
# 40   0.108387
# 53   0.108387
# 10   0.108387
# 62   0.108387
# 73   0.108387
# 88  -0.200000
# 96  -0.200000
# 97   0.108387
# 16  -0.200000
# 2   -0.200000
# 57  -0.200000
# 45  -0.200000

# %%
# set some rows as 'starred' for more example
data.loc[60, 'starred'] = 1
data.loc[67, 'starred'] = 1
data.loc[12, 'starred'] = 1
data.loc[98, 'starred'] = 1
data.loc[80, 'starred'] = 1
data.loc[59, 'starred'] = 1
data.loc[28, 'starred'] = 1
data.loc[73, 'starred'] = 1
data.loc[57, 'starred'] = 1

#update the fitness_score based on starring
data['fitness_score'] = data['similarity_score'] * 0.9 + data['normalized_connections'] * 0.1 + data['starred']
data = data.sort_values(by='fitness_score', ascending=False)
# print the updated dataframe
data.head(10)
# Out:
#       id                                          job_title  \
# 7      8                               HR Senior Specialist
# 60    61                               HR Senior Specialist
# 27    28              Seeking Human Resources Opportunities
# 67    68            Human Resources Specialist at Luxottica
# 55    56  Human Resources Coordinator at InterContinenta...
# 12    13  Human Resources Coordinator at InterContinenta...
# 100  101              Human Resources Generalist at Loparex
# 98    99                   Seeking Human Resources Position
# 80    81  Senior Human Resources Business Partner at Hei...
# 59    60                Aspiring Human Resources Specialist
#
#                                 location connection  fit  \
# 7                 San Francisco Bay Area      500+   NaN
# 60                San Francisco Bay Area      500+   NaN
# 27                     Chicago, Illinois        390  NaN
# 67            Greater New York City Area      500+   NaN
# 55                      Atlanta, Georgia      500+   NaN
# 12                      Atlanta, Georgia      500+   NaN
# 100  Raleigh-Durham, North Carolina Area      500+   NaN
# 98                Las Vegas, Nevada Area         48  NaN
# 80           Chattanooga, Tennessee Area        455  NaN
# 59            Greater New York City Area          1  NaN
#
#      normalized_connections  similarity_score  fitness_score  starred  \
# 7                     1.000          0.982888       1.984600        1
# 60                    1.000          0.982888       1.984600        1
# 27                    0.780          0.986173       1.965555        1
# 67                    1.000          0.961368       1.965231        1
# 55                    1.000          0.944081       1.949673        1
# 12                    1.000          0.944081       1.949673        1
# 100                   1.000          0.940202       1.946181        1
# 98                    0.096          0.986825       1.897743        1
# 80                    0.910          0.873379       1.877041        1
# 59                    0.002          0.969603       1.872843        1
#
#       ranking
# 7    0.108387
# 60   0.108387
# 27   0.108387
# 67   0.108387
# 55   0.108387
# 12   0.108387
# 100  0.108387
# 98   0.108387
# 80  -0.200000
# 59   0.108387

# %%
predictions = ranking_model(data)
df = data
df['ranking'] = predictions
df = df.sort_values(by='ranking', ascending=False)
# Out:
# Number of ranked items in training set: 11
# Number of ranked items in test set: 2
# [1]	valid_0's ndcg@5: 0.234639	valid_0's ndcg@10: 0.523947	valid_0's ndcg@20: 0.523947
# Training until validation scores don't improve for 50 rounds
# [2]	valid_0's ndcg@5: 0.234639	valid_0's ndcg@10: 0.523947	valid_0's ndcg@20: 0.523947
# [53]	valid_0's ndcg@5: 0.296082	valid_0's ndcg@10: 0.58539	valid_0's ndcg@20: 0.58539
# [54]	valid_0's ndcg@5: 0.296082	valid_0's ndcg@10: 0.58539	valid_0's ndcg@20: 0.58539
# [55]	valid_0's ndcg@5: 0.296082	valid_0's ndcg@10: 0.58539	valid_0's ndcg@20: 0.58539
# Early stopping, best iteration is:
# [5]	valid_0's ndcg@5: 0.296082	valid_0's ndcg@10: 0.58539	valid_0's ndcg@20: 0.58539

# %%
df.head(20)
# Out:
#       id                                          job_title  \
# 77    78             Human Resources Generalist at Schwan's
# 12    13  Human Resources Coordinator at InterContinenta...
# 42    43  Human Resources Coordinator at InterContinenta...
# 100  101              Human Resources Generalist at Loparex
# 64    65  Human Resources Coordinator at InterContinenta...
# 55    56  Human Resources Coordinator at InterContinenta...
# 102  103                     Always set them up for Success
# 67    68            Human Resources Specialist at Luxottica
# 33    34             People Development Coordinator at Ryan
# 37    38                               HR Senior Specialist
# 50    51                               HR Senior Specialist
# 25    26                               HR Senior Specialist
# 46    47             People Development Coordinator at Ryan
# 17    18             People Development Coordinator at Ryan
# 21    22             People Development Coordinator at Ryan
# 58    59             People Development Coordinator at Ryan
# 3      4             People Development Coordinator at Ryan
# 60    61                               HR Senior Specialist
# 7      8                               HR Senior Specialist
# 1      2  Native English Teacher at EPIK (English Progra...
#
#                                 location connection  fit  \
# 77           Amerika Birleşik Devletleri      500+   NaN
# 12                      Atlanta, Georgia      500+   NaN
# 42                      Atlanta, Georgia      500+   NaN
# 100  Raleigh-Durham, North Carolina Area      500+   NaN
# 64                      Atlanta, Georgia      500+   NaN
# 55                      Atlanta, Georgia      500+   NaN
# 102             Greater Los Angeles Area      500+   NaN
# 67            Greater New York City Area      500+   NaN
# 33                         Denton, Texas      500+   NaN
# 37                San Francisco Bay Area      500+   NaN
# 50                San Francisco Bay Area      500+   NaN
# 25                San Francisco Bay Area      500+   NaN
# 46                         Denton, Texas      500+   NaN
# 17                         Denton, Texas      500+   NaN
# 21                         Denton, Texas      500+   NaN
# 58                         Denton, Texas      500+   NaN
# 3                          Denton, Texas      500+   NaN
# 60                San Francisco Bay Area      500+   NaN
# 7                 San Francisco Bay Area      500+   NaN
# 1                                 Kanada      500+   NaN
#
#      normalized_connections  similarity_score  fitness_score  starred  \
# 77                      1.0          0.939072       0.945165        0
# 12                      1.0          0.944081       1.949673        1
# 42                      1.0          0.944081       0.949673        0
# 100                     1.0          0.940202       1.946181        1
# 64                      1.0          0.944081       0.949673        0
# 55                      1.0          0.944081       1.949673        1
# 102                     1.0          0.968243       0.971418        0
# 67                      1.0          0.961368       1.965231        1
# 33                      1.0          0.984712       0.986241        0
# 37                      1.0          0.982888       0.984600        0
# 50                      1.0          0.982888       0.984600        0
# 25                      1.0          0.982888       0.984600        0
# 46                      1.0          0.984712       0.986241        0
# 17                      1.0          0.984712       0.986241        0
# 21                      1.0          0.984712       0.986241        0
# 58                      1.0          0.984712       0.986241        0
# 3                       1.0          0.984712       0.986241        0
# 60                      1.0          0.982888       1.984600        1
# 7                       1.0          0.982888       1.984600        1
# 1                       1.0          0.899860       0.909874        0
#
#       ranking
# 77   0.180808
# 12   0.180808
# 42   0.180808
# 100  0.180808
# 64   0.180808
# 55   0.180808
# 102  0.173611
# 67   0.173611
# 33   0.076226
# 37   0.076226
# 50   0.076226
# 25   0.076226
# 46   0.076226
# 17   0.076226
# 21   0.076226
# 58   0.076226
# 3    0.076226
# 60   0.076226
# 7    0.076226
# 1    0.069620

# %%
#reset dataframe index
df = df.reset_index()
#find where the starred items are now
df.loc[df['starred'] == 1]
# Out:
#     index   id                                          job_title  \
# 1      12   13  Human Resources Coordinator at InterContinenta...
# 3     100  101              Human Resources Generalist at Loparex
# 5      55   56  Human Resources Coordinator at InterContinenta...
# 7      67   68            Human Resources Specialist at Luxottica
# 17     60   61                               HR Senior Specialist
# 18      7    8                               HR Senior Specialist
# 25     80   81  Senior Human Resources Business Partner at Hei...
# 27     27   28              Seeking Human Resources Opportunities
# 38     73   74                       Human Resources Professional
# 39     59   60                Aspiring Human Resources Specialist
# 41     98   99                   Seeking Human Resources Position
# 51     57   58              Aspiring Human Resources Professional
# 67     28   29  Aspiring Human Resources Management student se...
#
#                                location connection  fit  \
# 1                      Atlanta, Georgia      500+   NaN
# 3   Raleigh-Durham, North Carolina Area      500+   NaN
# 5                      Atlanta, Georgia      500+   NaN
# 7            Greater New York City Area      500+   NaN
# 17               San Francisco Bay Area      500+   NaN
# 18               San Francisco Bay Area      500+   NaN
# 25          Chattanooga, Tennessee Area        455  NaN
# 27                    Chicago, Illinois        390  NaN
# 38                  Greater Boston Area         16  NaN
# 39           Greater New York City Area          1  NaN
# 41               Las Vegas, Nevada Area         48  NaN
# 51  Raleigh-Durham, North Carolina Area         44  NaN
# 67                  Houston, Texas Area      500+   NaN
#
#     normalized_connections  similarity_score  fitness_score  starred   ranking
# 1                    1.000          0.944081       1.949673        1  0.180808
# 3                    1.000          0.940202       1.946181        1  0.180808
# 5                    1.000          0.944081       1.949673        1  0.180808
# 7                    1.000          0.961368       1.965231        1  0.173611
# 17                   1.000          0.982888       1.984600        1  0.076226
# 18                   1.000          0.982888       1.984600        1  0.076226
# 25                   0.910          0.873379       1.877041        1  0.069620
# 27                   0.780          0.986173       1.965555        1  0.037103
# 38                   0.032          0.951872       1.859885        1  0.023573
# 39                   0.002          0.969603       1.872843        1  0.023573
# 41                   0.096          0.986825       1.897743        1 -0.073813
# 51                   0.088          0.937843       1.852859        1 -0.080419
# 67                   1.000          0.853446       1.868102        1 -0.081098

# %% [markdown]
# ## Result for ranking

# %% [markdown]
# I have ranked candidates based on a fitness score that incorporates cosine similarity and normalized connections. I then rerank if someone manually stars a candidate.
# I then built a lightgbm ranking model to train on the data with the y='starred' and reranked the data based on the rankings obtained.
# However I then see that my previously starred candidates don't all appear at the top of the new ranking as the model didn't train well on such a small positive class (n=4).
# Adding more starred candidates (n=10) and retraining also gives better but still not great results.
