# %% [markdown]
# # Project 3
# ## Goal(s):
#
# Predict how fit the candidate is based on their available information (variable fit)
#
# ## Success Metric(s):
#
# Rank candidates based on a fitness score.
#
# Re-rank candidates when a candidate is starred.
#
# ## Bonus(es):
#
# We are interested in a robust algorithm, tell us how your solution works and show us how your ranking gets better with each starring action.
#
# How can we filter out candidates which in the first place should not be in this list?
#
# Can we determine a cut-off point that would work for other roles without losing high potential candidates?
#
# Do you have any ideas that we should explore so that we can even automate this procedure to prevent human bias?

# %%
# linear algebra
import numpy as np 

# data processing
import pandas as pd 

# data visualization
import seaborn as sns
# %matplotlib inline
from matplotlib import pyplot as plt
from matplotlib import style

# Algorithms
from sklearn import linear_model
from sklearn.linear_model import Perceptron
from sklearn.linear_model import SGDClassifier
from sklearn.svm import SVC, LinearSVC
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neural_network import MLPClassifier
import xgboost as xgb
import lightgbm as lgb


#Cross validation
from sklearn.model_selection import KFold, cross_val_score

#Other
from sklearn import metrics
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import classification_report
from sklearn.feature_selection import SelectKBest, chi2
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score

#class imbalance
from sklearn.metrics import f1_score
from sklearn.utils import resample

#NLP
import nltk
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.tokenize.treebank import TreebankWordDetokenizer
from transformers import AutoTokenizer, AutoModel
from sklearn.metrics.pairwise import cosine_similarity
import gensim.downloader as api
from gensim.models import KeyedVectors
# Out:
# [nltk_data] Downloading package punkt to /Users/natalie/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /Users/natalie/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/natalie/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# # Loading data and initial exploration

# %%
og_data = pd.read_excel('potential-talents.xlsx')
data = og_data
keywords = 'aspiring human resources'

# %%
data.head(3)
# Out:
#    id                                          job_title  \
# 0   1  2019 C.T. Bauer College of Business Graduate (...
# 1   2  Native English Teacher at EPIK (English Progra...
# 2   3              Aspiring Human Resources Professional
#
#                               location connection  fit
# 0                       Houston, Texas         85  NaN
# 1                               Kanada      500+   NaN
# 2  Raleigh-Durham, North Carolina Area         44  NaN

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104 entries, 0 to 103
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          104 non-null    int64
#  1   job_title   104 non-null    object
#  2   location    104 non-null    object
#  3   connection  104 non-null    object
#  4   fit         0 non-null      float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 4.2+ KB

# %%
data.isnull().sum()
# Out:
# id              0
# job_title       0
# location        0
# connection      0
# fit           104
# dtype: int64

# %% [markdown]
# Original data shape is 104, 5. The fit column is empty so we will remove it

# %%
data.drop('fit', axis=1, inplace=True)

# %%
data.columns
# Out:
# Index(['id', 'job_title', 'location', 'connection'], dtype='object')

# %% [markdown]
# Attributes:
# id : unique identifier for candidate (numeric)
#
# job_title : job title for candidate (text)
#
# location : geographical location for candidate (text)
#
# connections: number of connections candidate has, 500+ means over 500 (text)

# %%
data.describe()
# Out:
#                id
# count  104.000000
# mean    52.500000
# std     30.166206
# min      1.000000
# 25%     26.750000
# 50%     52.500000
# 75%     78.250000
# max    104.000000

# %% [markdown]
# # Add controls

# %% [markdown]
# I want to add 3 controls to my data so I can check the similarity code in particular

# %%
controls = pd.DataFrame({
    "id": [1111, 1112, 1113],
    "job_title": ['Machine learning', 'NA', 'artist'], "location":['x','x','x'], "connection": [150, 0, 500]
}, index=[104, 105, 106])

# Append a dataframe
#
data = data.append(controls)

# %%
data.tail()
# Out:
#        id                                         job_title  \
# 102   103                    Always set them up for Success
# 103   104  Director Of Administration at Excellence Logging
# 104  1111                                  Machine learning
# 105  1112                                                NA
# 106  1113                                            artist
#
#                      location connection
# 102  Greater Los Angeles Area      500+
# 103               Katy, Texas      500+
# 104                         x        150
# 105                         x          0
# 106                         x        500

# %% [markdown]
# # Exploring data deeper

# %%
for col in data.columns:
    print(f'{data[col].nunique()}: unique value in {col}')
# Out:
# 107: unique value in id
# 55: unique value in job_title
# 42: unique value in location
# 36: unique value in connection

# %% [markdown]
# Less job titles than rows so check if there are duplicates rows

# %%
df = data.drop(['id'], axis = 1)                    
print("Duplicates:", df.duplicated().sum())
# Out:
# Duplicates: 51

# %%
# look at those rows
df[df.duplicated(keep=False)]
# Out:
#                                             job_title  \
# 0   2019 C.T. Bauer College of Business Graduate (...
# 1   Native English Teacher at EPIK (English Progra...
# 2               Aspiring Human Resources Professional
# 3              People Development Coordinator at Ryan
# 4     Advisory Board Member at Celal Bayar University
# ..                                                ...
# 60                               HR Senior Specialist
# 61  Seeking Human Resources HRIS and Generalist Po...
# 62                      Student at Chapman University
# 63  SVP, CHRO, Marketing & Communications, CSR Off...
# 64  Human Resources Coordinator at InterContinenta...
#
#                                location connection
# 0                        Houston, Texas         85
# 1                                Kanada      500+
# 2   Raleigh-Durham, North Carolina Area         44
# 3                         Denton, Texas      500+
# 4                        İzmir, Türkiye      500+
# ..                                  ...        ...
# 60               San Francisco Bay Area      500+
# 61            Greater Philadelphia Area      500+
# 62              Lake Forest, California          2
# 63                  Houston, Texas Area      500+
# 64                     Atlanta, Georgia      500+
#
# [65 rows x 3 columns]

# %%
#clean up duplicates
newdf = df.drop_duplicates()                                    
data = pd.concat([data['id'], newdf], axis = 1).dropna(axis = 0)   
data = data.reset_index(drop = True)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56 entries, 0 to 55
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0
# A lot of accronyms are used so will need to replace them later.

# %%
acronyms = {'GIS': 'geographic information system', 
            'HRIS': 'human resources information system', 'MES': 'manufacturing execution system',
            'SVP': 'senior vice president', 'CHRO':'chief human resources officer', 'CSR': 'corporate social responsibility',
           'GPHR':'global professional in human resources', 'SPHR': 'senior professional in human resources'
           }

# %%
print('location: ', data.location.value_counts())
print('connections: ', data.connection.value_counts())
# Out:
# location:  Houston, Texas Area                    4
# x                                      3
# Greater New York City Area             3
# Raleigh-Durham, North Carolina Area    3
# Amerika Birleşik Devletleri            2
# Greater Philadelphia Area              2
# Kanada                                 2
# Greater Atlanta Area                   2
# Austin, Texas Area                     2
# San Francisco Bay Area                 1
# Dallas/Fort Worth Area                 1
# Greater Los Angeles Area               1
# Baltimore, Maryland                    1
# Monroe, Louisiana Area                 1
# Jackson, Mississippi Area              1
# Virginia Beach, Virginia               1
# Las Vegas, Nevada Area                 1
# New York, New York                     1
# Cape Girardeau, Missouri               1
# Los Angeles, California                1
# Houston, Texas                         1
# Bridgewater, Massachusetts             1
# İzmir, Türkiye                         1
# Greater Chicago Area                   1
# Chattanooga, Tennessee Area            1
# Milpitas, California                   1
# Gaithersburg, Maryland                 1
# Atlanta, Georgia                       1
# Chicago, Illinois                      1
# San Jose, California                   1
# Lake Forest, California                1
# Myrtle Beach, South Carolina Area      1
# Lafayette, Indiana                     1
# Long Beach, California                 1
# Greater Grand Rapids, Michigan Area    1
# Katy, Texas                            1
# Torrance, California                   1
# Denton, Texas                          1
# Greater Boston Area                    1
# Kokomo, Indiana Area                   1
# Highland, California                   1
# Baton Rouge, Louisiana Area            1
# Name: location, dtype: int64
# connections:  500+     18
# 57        2
# 4         2
# 7         2
# 48        1
# 71        1
# 39        1
# 40        1
# 500       1
# 44        1
# 174       1
# 64        1
# 49        1
# 349       1
# 18        1
# 52        1
# 50        1
# 103       1
# 415       1
# 155       1
# 1         1
# 409       1
# 455       1
# 0         1
# 150       1
# 85        1
# 212       1
# 19        1
# 82        1
# 16        1
# 268       1
# 9         1
# 390       1
# 5         1
# 2         1
# 61        1
# Name: connection, dtype: int64

# %% [markdown]
# # Cleaning and processing data

# %% [markdown]
# Before starting my NLP analysis I will follow some best practices including:
# 1. removing unwanted characters punctuation, special characters, from the text.
# 2. making lowercase, removing stop words, stemming and lemmatization
# 3. replacing acronyms, normalizing
#
# <!-- Data Splitting: Split the data into training, validation, and testing sets to build and evaluate models. It is essential to ensure that the distribution of the data is maintained across the different sets.
#
# Model Selection: Select an appropriate NLP algorithm for the task at hand, and compare the performance of different models to select the best one.
#
# Model Evaluation: Evaluate the model's performance on the test set and use appropriate metrics to measure the model's accuracy, precision, recall, and F1 score. -->

# %%
# Step 1 removing unwanted characters punctuation, special characters from the text.
data = data.replace({'job_title' : { "[\'!#)$%&(*+-./:;<=>?@[\]^_`{|}~\n]" : " "}}, regex=True)
data = data.replace({'location' : { "[\'!#)$%&(*+-./:;<=>?@[\]^_`{|}~\n]" : " "}}, regex=True)

# %%
#before making lowercase, rpleace all HR with human resources so it doesn't affect 'hr' string in words
data = data.replace({'HR': 'human resources'}, regex=True)
data.head(10)
# Out:
#    id                                          job_title  \
# 0   1  2019 C T  Bauer College of Business Graduate  ...
# 1   2  Native English Teacher at EPIK  English Progra...
# 2   3              Aspiring Human Resources Professional
# 3   4             People Development Coordinator at Ryan
# 4   5    Advisory Board Member at Celal Bayar University
# 5   6                Aspiring Human Resources Specialist
# 6   7  Student at Humber College and Aspiring Human R...
# 7   8                  human resources Senior Specialist
# 8  10  Seeking Human Resources human resourcesIS and ...
# 9  11                      Student at Chapman University
#
#                               location connection
# 0                       Houston  Texas         85
# 1                               Kanada      500+
# 2  Raleigh Durham  North Carolina Area         44
# 3                        Denton  Texas      500+
# 4                       İzmir  Türkiye      500+
# 5           Greater New York City Area          1
# 6                               Kanada         61
# 7               San Francisco Bay Area      500+
# 8            Greater Philadelphia Area      500+
# 9              Lake Forest  California          2

# %%
# Step 2 making lowercase, removing stop words, stemming and lemmatization
data['job_title'] = data['job_title'].str.lower()
data['location'] = data['location'].str.lower()

# %%
data.head(10)
# Out:
#    id                                          job_title  \
# 0   1  2019 c t  bauer college of business graduate  ...
# 1   2  native english teacher at epik  english progra...
# 2   3              aspiring human resources professional
# 3   4             people development coordinator at ryan
# 4   5    advisory board member at celal bayar university
# 5   6                aspiring human resources specialist
# 6   7  student at humber college and aspiring human r...
# 7   8                  human resources senior specialist
# 8  10  seeking human resources human resourcesis and ...
# 9  11                      student at chapman university
#
#                               location connection
# 0                       houston  texas         85
# 1                               kanada      500+
# 2  raleigh durham  north carolina area         44
# 3                        denton  texas      500+
# 4                      i̇zmir  türkiye      500+
# 5           greater new york city area          1
# 6                               kanada         61
# 7               san francisco bay area      500+
# 8            greater philadelphia area      500+
# 9              lake forest  california          2

# %%
#cleaning
stop_words = set(stopwords.words('english'))
for i in range (len(data)):
    word_tokens = word_tokenize(data['job_title'][i])
    tokens_without = [word for word in word_tokens if word not in stop_words]
    lemmatized_sentence = []
    for word in tokens_without:
        lemmatized_sentence.append(WordNetLemmatizer().lemmatize(word))
    data['job_title'][i] = TreebankWordDetokenizer().detokenize(lemmatized_sentence)
# Out:
# <ipython-input-242-fbb1aa942274>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['job_title'][i] = TreebankWordDetokenizer().detokenize(lemmatized_sentence)

# %%
data.head(2)
# Out:
#    id                                          job_title        location  \
# 0   1  2019 c bauer college business graduate magna c...  houston  texas
# 1   2  native english teacher epik english program korea          kanada
#
#   connection
# 0         85
# 1      500+

# %%
# Step 3 replacing acronyms, normalizing
#first we need to make all the keys/values of the previously defoned acronyms dict to be lower case
lc_acronyms = {k.lower(): v.lower() for k, v in acronyms.items()}
print(lc_acronyms)
data = data.replace(lc_acronyms, regex=True)
# Out:
# {'gis': 'geographic information system', 'hris': 'human resources information system', 'mes': 'manufacturing execution system', 'svp': 'senior vice president', 'chro': 'chief human resources officer', 'csr': 'corporate social responsibility', 'gphr': 'global professional in human resources', 'sphr': 'senior professional in human resources'}

# %%
print('new titles:', data['job_title'])
# Out:
# new titles: 0     2019 c bauer college business graduate magna c...
# 1     native english teacher epik english program korea
# 2                  aspiring human resource professional
# 3                   people development coordinator ryan
# 4          advisory board member celal bayar university
# 5                    aspiring human resource specialist
# 6     student humber college aspiring human resource...
# 7                      human resource senior specialist
# 8     seeking human resource human resourcesis gener...
# 9                            student chapman university
# 10    senior vice president chuman resourceso market...
# 11    human resource coordinator intercontinental bu...
# 12    aspiring human resource management student see...
# 13                   seeking human resource opportunity
# 14    experienced retail manager aspiring human reso...
# 15      human resource staffing recruiting professional
# 16                  human resource specialist luxottica
# 17    director human resource north america groupe b...
# 18    retired army national guard recruiter office m...
# 19            human resource generalist scottmadden inc
# 20    business management major aspiring human resou...
# 21    aspiring human resource manager seeking intern...
# 22                          human resource professional
# 23    nortia staffing seeking human resource payroll...
# 24    aspiring human resource professional passionat...
# 25    human resource conflict management policy proc...
# 26                     human resource generalist schwan
# 27    liberal art major aspiring human resource analyst
# 28                junior me engineer information system
# 29    senior human resource business partner heil en...
# 30    aspiring human resource professional energetic...
# 31    human resource manager endemol shine north ame...
# 32    human resource professional world leader gi so...
# 33    rrp brand portfolio executive jti japan tobacc...
# 34    information system specialist programmer love ...
# 35    bachelor science biology victoria university w...
# 36                      human resource management major
# 37                           director human resource ey
# 38      undergraduate research assistant styczynski lab
# 39            lead official western illinois university
# 40    seeking employment opportunity within customer...
# 41    admission representative community medical cen...
# 42    seeking human resource opportunity open travel...
# 43                   student westfield state university
# 44    student indiana university kokomo business man...
# 45                 aspiring human resource professional
# 46                                              student
# 47                      seeking human resource position
# 48    aspiring human resource manager graduating may...
# 49                    human resource generalist loparex
# 50             business intelligence analytics traveler
# 51                                   always set success
# 52           director administration excellence logging
# 53                                     machine learning
# 54                                                   na
# 55                                               artist
# Name: job_title, dtype: object

# %%
#we will normalize the connections to be between 0-1. We will count 500+ as 500

# Function to normalize scores to between 0-1
def normalize_score(score):
    if score == '500+ ':
        score = 500
    return float(score)/500

# Applying the function to the 'connection' column to create a new 'normalized_connections' column
data['normalized_connections'] = data['connection'].apply(normalize_score)

# %% [markdown]
# # Word embedding

# %%
#We will then calculate the similarity between the job titles and the given keyword (stored as variable 'keywords' in the top of the code, at first it we use 'aspiring human resources')

# Download the word2vec model
model_name = "word2vec-google-news-300"
word_vectors = api.load(model_name)

# Tokenize and encode the job titles using word2vec
job_title_encodings = data["job_title"].apply(
    lambda title: np.mean([word_vectors[word] for word in title.split() if word in word_vectors], axis=0)
)

# Compute the cosine similarity between the encoded job titles and the keyword
keyword_encoding = np.mean([word_vectors[word] for word in keywords.split() if word in word_vectors], axis=0)
similarity_scores = np.vstack(job_title_encodings.apply(lambda encoding: cosine_similarity(encoding.reshape(1, -1), keyword_encoding.reshape(1, -1)))).ravel()

# Add the similarity scores as a new column in the DataFrame
data["similarity_score"] = similarity_scores

# %%
data.head()
# Out:
#    id                                          job_title  \
# 0   1  2019 c bauer college business graduate magna c...
# 1   2  native english teacher epik english program korea
# 2   3               aspiring human resource professional
# 3   4                people development coordinator ryan
# 4   5       advisory board member celal bayar university
#
#                               location connection  normalized_connections  \
# 0                       houston  texas         85                   0.170
# 1                               kanada      500+                    1.000
# 2  raleigh durham  north carolina area         44                   0.088
# 3                        denton  texas      500+                    1.000
# 4                      i̇zmir  türkiye      500+                    1.000
#
#    similarity_score
# 0          0.561702
# 1          0.218221
# 2          0.872865
# 3          0.287687
# 4          0.208822

# %%
#We will then calculate the similarity between the job titles and the given keyword (stored as variable 'keywords' in the top of the code, at first it we use 'aspiring human resources')

# Load the BERT tokenizer and model
tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")
model = AutoModel.from_pretrained("bert-base-uncased")

# Tokenize and encode the job titles using BERT
job_title_encodings = data["job_title"].apply(
    lambda title: model(**tokenizer(title, return_tensors="pt")).pooler_output.detach().numpy()
)

# Compute the cosine similarity between the encoded job titles and the keyword
keyword_encoding = model(**tokenizer(keywords, return_tensors="pt")).pooler_output.detach().numpy()
similarity_scores = np.vstack(job_title_encodings.apply(lambda encoding: cosine_similarity(encoding, keyword_encoding))).ravel()

# Add the similarity scores as a new column in the DataFrame
data["similarity_score_BERT"] = similarity_scores
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertModel: ['cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.decoder.weight', 'cls.seq_relationship.weight', 'cls.predictions.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
data = data.sort_values(by='similarity_score', ascending=False)
data.head()
# Out:
#     id                                          job_title  \
# 2    3               aspiring human resource professional
# 45  97               aspiring human resource professional
# 5    6                 aspiring human resource specialist
# 21  73  aspiring human resource manager seeking intern...
# 22  74                        human resource professional
#
#                                location connection  normalized_connections  \
# 2   raleigh durham  north carolina area         44                   0.088
# 45                 kokomo  indiana area         71                   0.142
# 5            greater new york city area          1                   0.002
# 21                  houston  texas area          7                   0.014
# 22                  greater boston area         16                   0.032
#
#     similarity_score  similarity_score_BERT
# 2           0.872865               0.933594
# 45          0.872865               0.933594
# 5           0.836409               0.964565
# 21          0.822812               0.922119
# 22          0.798362               0.958796

# %%
data.tail()
# Out:
#       id                                          job_title  \
# 4      5       advisory board member celal bayar university
# 51   103                                 always set success
# 33    85  rrp brand portfolio executive jti japan tobacc...
# 55  1113                                             artist
# 54  1112                                                 na
#
#                      location connection  normalized_connections  \
# 4             i̇zmir  türkiye      500+                      1.0
# 51   greater los angeles area      500+                      1.0
# 33  greater philadelphia area      500+                      1.0
# 55                          x        500                     1.0
# 54                          x          0                     0.0
#
#     similarity_score  similarity_score_BERT
# 4           0.208822               0.839048
# 51          0.206629               0.981850
# 33          0.188941               0.875010
# 55          0.124317               0.975621
# 54          0.043954               0.943436

# %%
#reset dataframe index
find = data.reset_index()
#find where the starred items are now
find.loc[find['id'] > 1110]
# Out:
#     index    id         job_title location connection  normalized_connections  \
# 44     53  1111  machine learning        x        150                     0.3
# 54     55  1113            artist        x        500                     1.0
# 55     54  1112                na        x          0                     0.0
#
#     similarity_score  similarity_score_BERT
# 44          0.271537               0.908728
# 54          0.124317               0.975621
# 55          0.043954               0.943436

# %% [markdown]
# We can see that our controls show up quite low when sorting by word2vec similarity

# %%
#now make a new column fitness score based on an equation taking similarity_score (word2vec) and normalized_connections

# calculate the new column based on the equation
data['fitness_score'] = data['similarity_score'] * 0.9 + data['normalized_connections'] * 0.1
data = data.sort_values(by='fitness_score', ascending=False)
data.tail(20)
# Out:
#       id                                          job_title  \
# 38    90    undergraduate research assistant styczynski lab
# 34    86  information system specialist programmer love ...
# 52   104         director administration excellence logging
# 28    80              junior me engineer information system
# 40    92  seeking employment opportunity within customer...
# 1      2  native english teacher epik english program korea
# 44    96  student indiana university kokomo business man...
# 4      5       advisory board member celal bayar university
# 51   103                                 always set success
# 50   102           business intelligence analytics traveler
# 53  1111                                   machine learning
# 33    85  rrp brand portfolio executive jti japan tobacc...
# 43    95                 student westfield state university
# 35    87  bachelor science biology victoria university w...
# 41    93  admission representative community medical cen...
# 39    91          lead official western illinois university
# 9     11                         student chapman university
# 55  1113                                             artist
# 46    98                                            student
# 54  1112                                                 na
#
#                              location connection  normalized_connections  \
# 38               greater atlanta area        155                   0.310
# 34             gaithersburg  maryland          4                   0.008
# 52                        katy  texas      500+                    1.000
# 28  myrtle beach  south carolina area         52                   0.104
# 40               torrance  california         64                   0.128
# 1                              kanada      500+                    1.000
# 44                 lafayette  indiana         19                   0.038
# 4                     i̇zmir  türkiye      500+                    1.000
# 51           greater los angeles area      500+                    1.000
# 50         greater new york city area         49                   0.098
# 53                                  x        150                   0.300
# 33          greater philadelphia area      500+                    1.000
# 43         bridgewater  massachusetts         57                   0.114
# 35                baltimore  maryland         40                   0.080
# 41             long beach  california          9                   0.018
# 39               greater chicago area         39                   0.078
# 9             lake forest  california          2                   0.004
# 55                                  x        500                   1.000
# 46                houston  texas area          4                   0.008
# 54                                  x          0                   0.000
#
#     similarity_score  similarity_score_BERT  fitness_score
# 38          0.338278               0.807109       0.335450
# 34          0.358062               0.885482       0.323056
# 52          0.240087               0.946331       0.316078
# 28          0.335249               0.982931       0.312124
# 40          0.324646               0.893608       0.304981
# 1           0.218221               0.902306       0.296399
# 44          0.322475               0.842853       0.294028
# 4           0.208822               0.839048       0.287940
# 51          0.206629               0.981850       0.285966
# 50          0.295893               0.859830       0.276104
# 53          0.271537               0.908728       0.274383
# 33          0.188941               0.875010       0.270047
# 43          0.277485               0.923465       0.261137
# 35          0.273652               0.908368       0.254287
# 41          0.265030               0.923691       0.240327
# 39          0.257085               0.892215       0.239177
# 9           0.237574               0.960531       0.214216
# 55          0.124317               0.975621       0.211886
# 46          0.222213               0.950692       0.200791
# 54          0.043954               0.943436       0.039558

# %% [markdown]
# # Starring candidates

# %%
data.head(10)
# Out:
#      id                                          job_title  \
# 45   97               aspiring human resource professional
# 2     3               aspiring human resource professional
# 8    10  seeking human resource human resourcesis gener...
# 12   27  aspiring human resource management student see...
# 5     6                 aspiring human resource specialist
# 49  101                  human resource generalist loparex
# 26   78                   human resource generalist schwan
# 21   73  aspiring human resource manager seeking intern...
# 13   28                 seeking human resource opportunity
# 22   74                        human resource professional
#
#                                location connection  normalized_connections  \
# 45                 kokomo  indiana area         71                   0.142
# 2   raleigh durham  north carolina area         44                   0.088
# 8             greater philadelphia area      500+                    1.000
# 12                  houston  texas area      500+                    1.000
# 5            greater new york city area          1                   0.002
# 49  raleigh durham  north carolina area      500+                    1.000
# 26          amerika birleşik devletleri      500+                    1.000
# 21                  houston  texas area          7                   0.014
# 13                    chicago  illinois        390                   0.780
# 22                  greater boston area         16                   0.032
#
#     similarity_score  similarity_score_BERT  fitness_score
# 45          0.872865               0.933594       0.799779
# 2           0.872865               0.933594       0.794379
# 8           0.747503               0.845393       0.772752
# 12          0.737665               0.936784       0.763899
# 5           0.836409               0.964565       0.752968
# 49          0.724036               0.980470       0.751632
# 26          0.724036               0.978520       0.751632
# 21          0.822812               0.922119       0.741931
# 13          0.721559               0.975341       0.727403
# 22          0.798362               0.958796       0.721726

# %%
# add a new column named 'starred' and set all values to 0
data['starred'] = 0

# set the value of the id 3 in 'starred' to 1 as an example
data.loc[data['id'] == 3, 'starred'] = 1

#update the fitness_score based on starring
data['fitness_score'] = data['similarity_score'] * 0.9 + data['normalized_connections'] * 0.1 + data['starred']
data = data.sort_values(by='fitness_score', ascending=False)
# print the updated dataframe
data.head(10)
# Out:
#      id                                          job_title  \
# 2     3               aspiring human resource professional
# 45   97               aspiring human resource professional
# 8    10  seeking human resource human resourcesis gener...
# 12   27  aspiring human resource management student see...
# 5     6                 aspiring human resource specialist
# 49  101                  human resource generalist loparex
# 26   78                   human resource generalist schwan
# 21   73  aspiring human resource manager seeking intern...
# 13   28                 seeking human resource opportunity
# 22   74                        human resource professional
#
#                                location connection  normalized_connections  \
# 2   raleigh durham  north carolina area         44                   0.088
# 45                 kokomo  indiana area         71                   0.142
# 8             greater philadelphia area      500+                    1.000
# 12                  houston  texas area      500+                    1.000
# 5            greater new york city area          1                   0.002
# 49  raleigh durham  north carolina area      500+                    1.000
# 26          amerika birleşik devletleri      500+                    1.000
# 21                  houston  texas area          7                   0.014
# 13                    chicago  illinois        390                   0.780
# 22                  greater boston area         16                   0.032
#
#     similarity_score  similarity_score_BERT  fitness_score  starred
# 2           0.872865               0.933594       1.794379        1
# 45          0.872865               0.933594       0.799779        0
# 8           0.747503               0.845393       0.772752        0
# 12          0.737665               0.936784       0.763899        0
# 5           0.836409               0.964565       0.752968        0
# 49          0.724036               0.980470       0.751632        0
# 26          0.724036               0.978520       0.751632        0
# 21          0.822812               0.922119       0.741931        0
# 13          0.721559               0.975341       0.727403        0
# 22          0.798362               0.958796       0.721726        0

# %%
# set the value in 'starred' to 1 as more example, for ids: 27, 6, 73
data.loc[data['id'] == 27, 'starred'] = 1
data.loc[data['id'] == 6, 'starred'] = 1
data.loc[data['id'] == 73, 'starred'] = 1

#update the fitness_score based on starring
data['fitness_score'] = data['similarity_score'] * 0.9 + data['normalized_connections'] * 0.1 + data['starred']
data = data.sort_values(by='fitness_score', ascending=False)
# print the updated dataframe
data.head(10)
# Out:
#      id                                          job_title  \
# 2     3               aspiring human resource professional
# 12   27  aspiring human resource management student see...
# 5     6                 aspiring human resource specialist
# 21   73  aspiring human resource manager seeking intern...
# 45   97               aspiring human resource professional
# 8    10  seeking human resource human resourcesis gener...
# 49  101                  human resource generalist loparex
# 26   78                   human resource generalist schwan
# 13   28                 seeking human resource opportunity
# 22   74                        human resource professional
#
#                                location connection  normalized_connections  \
# 2   raleigh durham  north carolina area         44                   0.088
# 12                  houston  texas area      500+                    1.000
# 5            greater new york city area          1                   0.002
# 21                  houston  texas area          7                   0.014
# 45                 kokomo  indiana area         71                   0.142
# 8             greater philadelphia area      500+                    1.000
# 49  raleigh durham  north carolina area      500+                    1.000
# 26          amerika birleşik devletleri      500+                    1.000
# 13                    chicago  illinois        390                   0.780
# 22                  greater boston area         16                   0.032
#
#     similarity_score  similarity_score_BERT  fitness_score  starred
# 2           0.872865               0.933594       1.794379        1
# 12          0.737665               0.936784       1.763899        1
# 5           0.836409               0.964565       1.752968        1
# 21          0.822812               0.922119       1.741931        1
# 45          0.872865               0.933594       0.799779        0
# 8           0.747503               0.845393       0.772752        0
# 49          0.724036               0.980470       0.751632        0
# 26          0.724036               0.978520       0.751632        0
# 13          0.721559               0.975341       0.727403        0
# 22          0.798362               0.958796       0.721726        0

# %% [markdown]
# # Models

# %%
def ranking_model(data):
    #make x and y
    feature_cols = ['normalized_connections', 'similarity_score']
    X = data[feature_cols]
    y = data.starred 
    
    #split data into training and testing, check both have starred items
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
    # Make sure at least one example of data with positive supervisory signal is in the training set
    print("Number of ranked items in training set:", y_train.sum())
    print("Number of ranked items in test set:",y_test.sum())
    while y_train.sum() ==0 or y_test.sum()== 0:
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
        # Make sure at least one example of data with positive supervisory signal is in the training set
        print("Number of ranked items in training set:", y_train.sum())
        print("Number of ranked items in test set:",y_test.sum())
    X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2)
    
    #define queries
    query_train = [X_train.shape[0]]
    query_val = [X_val.shape[0]]
    query_test = [X_test.shape[0]]

    # Train the LightGBM model
    
    gbm = lgb.LGBMRanker(
    objective="lambdarank",
    metric="ndcg",)
    
    gbm.set_params(min_child_samples=2)
    
    gbm.fit(X_train, y_train, group=query_train,
        eval_set=[(X_val, y_val)], eval_group=[query_val],
        eval_at=[5, 10, 20], early_stopping_rounds=50)


    # predict on test set and return
    return gbm.predict(X)

# %%
predictions = ranking_model(data)
# Out:
# Number of ranked items in training set: 3
# Number of ranked items in test set: 1
# [1]	valid_0's ndcg@5: 0.877215	valid_0's ndcg@10: 0.877215	valid_0's ndcg@20: 0.877215
# Training until validation scores don't improve for 50 rounds
# [2]	valid_0's ndcg@5: 0.877215	valid_0's ndcg@10: 0.877215	valid_0's ndcg@20: 0.877215
# %%
from keras.models import Model
from keras.layers import Input, Dense, Dropout
from keras.optimizers import Adam
from keras.losses import binary_crossentropy
from keras.callbacks import EarlyStopping

# Define the RankNet model
def ranknet_model(num_features):
    input1 = Input(shape=(num_features,))
    input2 = Input(shape=(num_features,))

    shared_layer1 = Dense(64, activation='relu')
    shared_layer2 = Dense(32, activation='relu')

    h1 = shared_layer1(input1)
    h1 = Dropout(0.5)(h1)
    h2 = shared_layer2(h1)

    h3 = shared_layer1(input2)
    h3 = Dropout(0.5)(h3)
    h4 = shared_layer2(h3)

    s = Dense(1, activation='sigmoid', name='main_output')(h2-h4)

    model = Model(inputs=[input1, input2], outputs=s)

    return model

# Define a function to train the RankNet model
def train_ranknet_model(X_train, y_train, X_val, y_val, num_epochs=100, batch_size=128, learning_rate=0.001):
    num_features = X_train.shape[1]

    model = ranknet_model(num_features)

    optimizer = Adam(lr=learning_rate)

    model.compile(optimizer=optimizer, loss=binary_crossentropy)

    early_stopping = EarlyStopping(monitor='val_loss', patience=10, verbose=1, mode='auto')

    model.fit([X_train, X_train], y_train,
              validation_data=([X_val, X_val], y_val),
              epochs=num_epochs,
              batch_size=batch_size,
              callbacks=[early_stopping])

    return model


def ranking_model2(data):
    #make x and y
    feature_cols = ['normalized_connections', 'similarity_score']
    X = data[feature_cols]
    y = data.starred 
    
    #split data into training and testing, check both have starred items
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
    # Make sure at least one example of data with positive supervisory signal is in the training set
    print("Number of ranked items in training set:", y_train.sum())
    print("Number of ranked items in test set:",y_test.sum())
    while y_train.sum() ==0 or y_test.sum()== 0:
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
        # Make sure at least one example of data with positive supervisory signal is in the training set
        print("Number of ranked items in training set:", y_train.sum())
        print("Number of ranked items in test set:",y_test.sum())
    
    model = train_ranknet_model(X_train, y_train, X_test, y_test)

    return model

# %%
model2 = ranking_model2(data)
n1 = data[['normalized_connections']]
n1 = n1.values
n2 = data[['similarity_score']]
n2 = n2.values 
model2.predict(n1, n2)
# Out:
# Number of ranked items in training set: 8
# Number of ranked items in test set: 2
# Epoch 1/100
# /opt/anaconda3/lib/python3.8/site-packages/keras/optimizers/legacy/adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# 1/1 [==============================] - 1s 894ms/step - loss: 0.7082 - val_loss: 0.6928
# Epoch 2/100
# 1/1 [==============================] - 0s 27ms/step - loss: 0.7051 - val_loss: 0.6925
# Epoch 3/100
# 1/1 [==============================] - 0s 29ms/step - loss: 0.6874 - val_loss: 0.6921
# Epoch 4/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.6980 - val_loss: 0.6918
# Epoch 5/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.6967 - val_loss: 0.6915
# Epoch 6/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.7040 - val_loss: 0.6912
# Epoch 7/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.6933 - val_loss: 0.6908
# Epoch 8/100
# 1/1 [==============================] - 0s 37ms/step - loss: 0.7024 - val_loss: 0.6905
# Epoch 9/100
# Epoch 96/100
# 1/1 [==============================] - 0s 26ms/step - loss: 0.6629 - val_loss: 0.6627
# Epoch 97/100
# 1/1 [==============================] - 0s 28ms/step - loss: 0.6760 - val_loss: 0.6624
# Epoch 98/100
# 1/1 [==============================] - 0s 26ms/step - loss: 0.6651 - val_loss: 0.6621
# Epoch 99/100
# 1/1 [==============================] - 0s 28ms/step - loss: 0.6675 - val_loss: 0.6618
# Epoch 100/100
# 1/1 [==============================] - 0s 28ms/step - loss: 0.6589 - val_loss: 0.6615

# %% [markdown]
# # Updating fitness and ranking

# %%
#rank based on model output
df = data
df['ranking'] = predictions
df = df.sort_values(by="ranking", ascending=False)

# %%
df.head()
# Out:
#     id                                          job_title  \
# 5    6                 aspiring human resource specialist
# 21  73  aspiring human resource manager seeking intern...
# 2    3               aspiring human resource professional
# 45  97               aspiring human resource professional
# 20  72  business management major aspiring human resou...
#
#                                location connection  normalized_connections  \
# 5            greater new york city area          1                   0.002
# 21                  houston  texas area          7                   0.014
# 2   raleigh durham  north carolina area         44                   0.088
# 45                 kokomo  indiana area         71                   0.142
# 20               monroe  louisiana area          5                   0.010
#
#     similarity_score  similarity_score_BERT  fitness_score  starred   ranking
# 5           0.836409               0.964565       1.752968        1  0.633960
# 21          0.822812               0.922119       1.741931        1  0.633960
# 2           0.872865               0.933594       1.794379        1  0.268402
# 45          0.872865               0.933594       0.799779        0  0.268402
# 20          0.716674               0.931661       0.646006        0 -0.350651

# %%
#reset dataframe index
df = df.reset_index()
#find where the starred items are now
df.loc[df['starred'] == 1]
# Out:
#     index  id                                          job_title  \
# 0       5   6                 aspiring human resource specialist
# 1      21  73  aspiring human resource manager seeking intern...
# 2       2   3               aspiring human resource professional
# 15     12  27  aspiring human resource management student see...
#
#                                location connection  normalized_connections  \
# 0            greater new york city area          1                   0.002
# 1                   houston  texas area          7                   0.014
# 2   raleigh durham  north carolina area         44                   0.088
# 15                  houston  texas area      500+                    1.000
#
#     similarity_score  similarity_score_BERT  fitness_score  starred   ranking
# 0           0.836409               0.964565       1.752968        1  0.633960
# 1           0.822812               0.922119       1.741931        1  0.633960
# 2           0.872865               0.933594       1.794379        1  0.268402
# 15          0.737665               0.936784       1.763899        1 -0.651039

# %% [markdown]
# Starred rows are towards the top

# %% [markdown]
# # Trying with more starred candidates

# %%
data.head(20)
# Out:
#      id                                          job_title  \
# 2     3               aspiring human resource professional
# 12   27  aspiring human resource management student see...
# 5     6                 aspiring human resource specialist
# 21   73  aspiring human resource manager seeking intern...
# 45   97               aspiring human resource professional
# 8    10  seeking human resource human resourcesis gener...
# 49  101                  human resource generalist loparex
# 26   78                   human resource generalist schwan
# 13   28                 seeking human resource opportunity
# 22   74                        human resource professional
# 15   67    human resource staffing recruiting professional
# 16   68                human resource specialist luxottica
# 6     7  student humber college aspiring human resource...
# 7     8                   human resource senior specialist
# 48  100  aspiring human resource manager graduating may...
# 23   75  nortia staffing seeking human resource payroll...
# 30   82  aspiring human resource professional energetic...
# 24   76  aspiring human resource professional passionat...
# 14   66  experienced retail manager aspiring human reso...
# 19   71          human resource generalist scottmadden inc
#
#                                location connection  normalized_connections  \
# 2   raleigh durham  north carolina area         44                   0.088
# 12                  houston  texas area      500+                    1.000
# 5            greater new york city area          1                   0.002
# 21                  houston  texas area          7                   0.014
# 45                 kokomo  indiana area         71                   0.142
# 8             greater philadelphia area      500+                    1.000
# 49  raleigh durham  north carolina area      500+                    1.000
# 26          amerika birleşik devletleri      500+                    1.000
# 13                    chicago  illinois        390                   0.780
# 22                  greater boston area         16                   0.032
# 15            jackson  mississippi area      500+                    1.000
# 16           greater new york city area      500+                    1.000
# 6                                kanada         61                   0.122
# 7                san francisco bay area      500+                    1.000
# 48             cape girardeau  missouri        103                   0.206
# 23                 san jose  california      500+                    1.000
# 30                   austin  texas area        174                   0.348
# 24                   new york  new york        212                   0.424
# 14                   austin  texas area         57                   0.114
# 19  raleigh durham  north carolina area      500+                    1.000
#
#     similarity_score  similarity_score_BERT  fitness_score  starred   ranking
# 2           0.872865               0.933594       1.794379        1  0.268402
# 12          0.737665               0.936784       1.763899        1 -0.651039
# 5           0.836409               0.964565       1.752968        1  0.633960
# 21          0.822812               0.922119       1.741931        1  0.633960
# 45          0.872865               0.933594       0.799779        0  0.268402
# 8           0.747503               0.845393       0.772752        0 -0.651039
# 49          0.724036               0.980470       0.751632        0 -0.651039
# 26          0.724036               0.978520       0.751632        0 -0.651039
# 13          0.721559               0.975341       0.727403        0 -0.651039
# 22          0.798362               0.958796       0.721726        0 -0.651039
# 15          0.684689               0.890210       0.716220        0 -0.651039
# 16          0.674604               0.940522       0.707144        0 -0.651039
# 6           0.769982               0.900687       0.705184        0 -0.651039
# 7           0.638090               0.961523       0.674281        0 -0.651039
# 48          0.722811               0.906839       0.671130        0 -0.651039
# 23          0.632145               0.963002       0.668930        0 -0.651039
# 30          0.700400               0.919451       0.665160        0 -0.651039
# 24          0.690302               0.863759       0.663672        0 -0.651039
# 14          0.722728               0.844770       0.661855        0 -0.651039
# 19          0.611949               0.927363       0.650754        0 -0.651039

# %%
# set the value in 'starred' to 1 as more example, for ids: 101, 78, 74, 68, 8, 82
data.loc[data['id'] == 101, 'starred'] = 1
data.loc[data['id'] == 78, 'starred'] = 1
data.loc[data['id'] == 74, 'starred'] = 1
data.loc[data['id'] == 68, 'starred'] = 1
data.loc[data['id'] == 8, 'starred'] = 1
data.loc[data['id'] == 82, 'starred'] = 1

#update the fitness_score based on starring
data['fitness_score'] = data['similarity_score'] * 0.9 + data['normalized_connections'] * 0.1 + data['starred']
data = data.sort_values(by='fitness_score', ascending=False)
# print the updated dataframe
data.head(10)
# Out:
#      id                                          job_title  \
# 2     3               aspiring human resource professional
# 12   27  aspiring human resource management student see...
# 5     6                 aspiring human resource specialist
# 49  101                  human resource generalist loparex
# 26   78                   human resource generalist schwan
# 21   73  aspiring human resource manager seeking intern...
# 22   74                        human resource professional
# 16   68                human resource specialist luxottica
# 7     8                   human resource senior specialist
# 30   82  aspiring human resource professional energetic...
# [42]	valid_0's ndcg@5: 0.650921	valid_0's ndcg@10: 0.650921	valid_0's ndcg@20: 0.650921
# [43]	valid_0's ndcg@5: 0.650921	valid_0's ndcg@10: 0.650921	valid_0's ndcg@20: 0.650921
# [44]	valid_0's ndcg@5: 0.650921	valid_0's ndcg@10: 0.650921	valid_0's ndcg@20: 0.650921
# [45]	valid_0's ndcg@5: 0.650921	valid_0's ndcg@10: 0.650921	valid_0's ndcg@20: 0.650921
# [46]	valid_0's ndcg@5: 0.650921	valid_0's ndcg@10: 0.650921	valid_0's ndcg@20: 0.650921
# [47]	valid_0's ndcg@5: 0.650921	valid_0's ndcg@10: 0.650921	valid_0's ndcg@20: 0.650921
# [48]	valid_0's ndcg@5: 0.650921	valid_0's ndcg@10: 0.650921	valid_0's ndcg@20: 0.650921
# [49]	valid_0's ndcg@5: 0.650921	valid_0's ndcg@10: 0.650921	valid_0's ndcg@20: 0.650921
# [50]	valid_0's ndcg@5: 0.650921	valid_0's ndcg@10: 0.650921	valid_0's ndcg@20: 0.650921
# [51]	valid_0's ndcg@5: 0.650921	valid_0's ndcg@10: 0.650921	valid_0's ndcg@20: 0.650921
# Early stopping, best iteration is:
# [1]	valid_0's ndcg@5: 0.877215	valid_0's ndcg@10: 0.877215	valid_0's ndcg@20: 0.877215

# %%
df.head(20)
# Out:
#      id                                          job_title  \
# 2     3               aspiring human resource professional
# 5     6                 aspiring human resource specialist
# 21   73  aspiring human resource manager seeking intern...
# 22   74                        human resource professional
# 49  101                  human resource generalist loparex
# 26   78                   human resource generalist schwan
# 16   68                human resource specialist luxottica
# 15   67    human resource staffing recruiting professional
# 45   97               aspiring human resource professional
# 8    10  seeking human resource human resourcesis gener...
# 6     7  student humber college aspiring human resource...
# 12   27  aspiring human resource management student see...
# 14   66  experienced retail manager aspiring human reso...
# 36   88                    human resource management major
# 27   79  liberal art major aspiring human resource analyst
# 47   99                    seeking human resource position
# 13   28                 seeking human resource opportunity
# 30   82  aspiring human resource professional energetic...
# 24   76  aspiring human resource professional passionat...
# 48  100  aspiring human resource manager graduating may...
#
#                                location connection  normalized_connections  \
# 2   raleigh durham  north carolina area         44                   0.088
# 5            greater new york city area          1                   0.002
# 21                  houston  texas area          7                   0.014
# 22                  greater boston area         16                   0.032
# 49  raleigh durham  north carolina area      500+                    1.000
# 26          amerika birleşik devletleri      500+                    1.000
# 16           greater new york city area      500+                    1.000
# 15            jackson  mississippi area      500+                    1.000
# 45                 kokomo  indiana area         71                   0.142
# 8             greater philadelphia area      500+                    1.000
# 6                                kanada         61                   0.122
# 12                  houston  texas area      500+                    1.000
# 14                   austin  texas area         57                   0.114
# 36                 milpitas  california         18                   0.036
# 27          baton rouge  louisiana area          7                   0.014
# 47               las vegas  nevada area         48                   0.096
# 13                    chicago  illinois        390                   0.780
# 30                   austin  texas area        174                   0.348
# 24                   new york  new york        212                   0.424
# 48             cape girardeau  missouri        103                   0.206
#
#     similarity_score  similarity_score_BERT  fitness_score  starred   ranking
# 2           0.872865               0.933594       1.794379        1  0.200000
# 5           0.836409               0.964565       1.752968        1  0.200000
# 21          0.822812               0.922119       1.741931        1  0.200000
# 22          0.798362               0.958796       1.721726        1  0.200000
# 49          0.724036               0.980470       1.751632        1  0.200000
# 26          0.724036               0.978520       1.751632        1  0.200000
# 16          0.674604               0.940522       1.707144        1  0.200000
# 15          0.684689               0.890210       0.716220        0  0.200000
# 45          0.872865               0.933594       0.799779        0  0.175538
# 8           0.747503               0.845393       0.772752        0  0.175538
# 6           0.769982               0.900687       0.705184        0  0.175538
# 12          0.737665               0.936784       1.763899        1  0.175538
# 14          0.722728               0.844770       0.661855        0 -0.200000
# 36          0.673330               0.856519       0.609597        0 -0.200000
# 27          0.679399               0.899233       0.612859        0 -0.200000
# 47          0.690652               0.959093       0.631187        0 -0.200000
# 13          0.721559               0.975341       0.727403        0 -0.200000
# 30          0.700400               0.919451       1.665160        1 -0.200000
# 24          0.690302               0.863759       0.663672        0 -0.200000
# 48          0.722811               0.906839       0.671130        0 -0.200000

# %%
#reset dataframe index
df = df.reset_index()
#find where the starred items are now
df.loc[df['starred'] == 1]
# Out:
#     index   id                                          job_title  \
# 0       2    3               aspiring human resource professional
# 1       5    6                 aspiring human resource specialist
# 2      21   73  aspiring human resource manager seeking intern...
# 3      22   74                        human resource professional
# 4      49  101                  human resource generalist loparex
# 5      26   78                   human resource generalist schwan
# 6      16   68                human resource specialist luxottica
# 11     12   27  aspiring human resource management student see...
# 17     30   82  aspiring human resource professional energetic...
# 41      7    8                   human resource senior specialist
#
#                                location connection  normalized_connections  \
# 0   raleigh durham  north carolina area         44                   0.088
# 1            greater new york city area          1                   0.002
# 2                   houston  texas area          7                   0.014
# 3                   greater boston area         16                   0.032
# 4   raleigh durham  north carolina area      500+                    1.000
# 5           amerika birleşik devletleri      500+                    1.000
# 6            greater new york city area      500+                    1.000
# 11                  houston  texas area      500+                    1.000
# 17                   austin  texas area        174                   0.348
# 41               san francisco bay area      500+                    1.000
#
#     similarity_score  similarity_score_BERT  fitness_score  starred   ranking
# 0           0.872865               0.933594       1.794379        1  0.200000
# 1           0.836409               0.964565       1.752968        1  0.200000
# 2           0.822812               0.922119       1.741931        1  0.200000
# 3           0.798362               0.958796       1.721726        1  0.200000
# 4           0.724036               0.980470       1.751632        1  0.200000
# 5           0.724036               0.978520       1.751632        1  0.200000
# 6           0.674604               0.940522       1.707144        1  0.200000
# 11          0.737665               0.936784       1.763899        1  0.175538
# 17          0.700400               0.919451       1.665160        1 -0.200000
# 41          0.638090               0.961523       1.674281        1 -0.200000

# %% [markdown]
# Problem: All the ranking come up as 0? Starred candidates are distributed throughout

# %% [markdown]
# ## Result for ranking

# %% [markdown]
# I have ranked candidates based on a fitness score that incorporates cosine similarity and normalized connections. I then rerank if someone manually stars a candidate.
# I then built a lightgbm ranking model to train on the data with the y='starred' and reranked the data based on the rankings obtained.
# However I then see that my previously starred candidates don't all appear at the top of the new ranking as the model didn't train well on such a small positive class (n=4).
# Adding more starred candidates (n=10) and retraining also gives better but still not great results.
